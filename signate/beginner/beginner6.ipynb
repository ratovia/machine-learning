# %%
import pandas as pd
p8 = pd.read_csv("sub8.csv", index_col=0,header=None,names=('A'))
p7 = pd.read_csv("sub7.csv", index_col=0,header=None,names=('B'))
p6 = pd.read_csv("sub6.csv", index_col=0,header=None,names=('C'))
p5 = pd.read_csv("submit.csv", index_col=0,header=None,names=('D'))

# %%
data = pd.concat([p8,p7,p6,p5] ,axis=1)
data
# Out:
#               A         B         C         D
# 0      1.848359  0.797013  0.850536  0.780742
# 1      0.125518  0.125907  0.048301  0.070759
# 2      0.032504  0.019311  0.022053  0.026249
# 3      0.002363  0.001939  0.003117  0.003861
# 4      0.051973  0.071966  0.044443  0.054852
# ...         ...       ...       ...       ...
# 18045  0.008039  0.010275  0.008398  0.014220
# 18046  0.015210  0.007965  0.006346  0.005528
# 18047  0.081826  0.070960  0.108576  0.065332
# 18048  0.003002  0.004569  0.008486  0.007232
# 18049  0.098933  0.072893  0.111859  0.139836
#
# [18050 rows x 4 columns]

# %%
data["med"] = [ np.median([data["A"][i],data["B"][i],data["C"][i],data["D"][i]]) for i in range(len(data)) ]
data
# Out:
#               A         B         C         D       med
# 0      1.848359  0.797013  0.850536  0.780742  0.823774
# 1      0.125518  0.125907  0.048301  0.070759  0.098139
# 2      0.032504  0.019311  0.022053  0.026249  0.024151
# 3      0.002363  0.001939  0.003117  0.003861  0.002740
# 4      0.051973  0.071966  0.044443  0.054852  0.053413
# ...         ...       ...       ...       ...       ...
# 18045  0.008039  0.010275  0.008398  0.014220  0.009337
# 18046  0.015210  0.007965  0.006346  0.005528  0.007155
# 18047  0.081826  0.070960  0.108576  0.065332  0.076393
# 18048  0.003002  0.004569  0.008486  0.007232  0.005900
# 18049  0.098933  0.072893  0.111859  0.139836  0.105396
#
# [18050 rows x 5 columns]

# %%
data.drop("A","B","C","D"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('A', 'B', 'C', 'D')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-637726e4e501> in <module>
# ...
